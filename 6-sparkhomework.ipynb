# %% [markdown]
# # Spark Dataframe Homework

# %% [markdown]
# Now, that we have a learnt a lot , it's time to see for yourself how much progress you have made.Good luck!!!

# %% [markdown]
# #### Use the inrix.csv file and segments.csv to Answer and complete the  tasks below!

# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://downloads.apache.org/spark/spark-3.0.1/spark-3.0.1-bin-hadoop2.7.tgz
# !tar xf spark-3.0.1-bin-hadoop2.7.tgz
# !pip install -q findspark

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.0.1-bin-hadoop2.7"
import findspark
findspark.init()

# %% [markdown]
# #### Start a simple Spark Session

# %% [markdown]
# #### Load the inrix CSV File

# %% [markdown]
# ####Read the data into a dataframe

# %% [markdown]
# ###Display 5 elements from the dataframe

# %% [markdown]
# ###Display the datatypes of the columns

# %% [markdown]
# ###Print the schema

# %% [markdown]
# ###Rename the Code and C-Value columns to code and cvalue and display the dataframe again

# %% [markdown]
# #### Display the column names again

# %% [markdown]
# #### Use describe() to learn about the DataFrame.(Hint: Don't forget to use .show())

# %% [markdown]
# ###Find all the rows that have null values and fill them 0 and display results

# %% [markdown]
# ###Change the datatype of the time column from string to timestamp

# %% [markdown]
# ###Change the datatype of column Travel to float.Also,print schema again

# %% [markdown]
# ###Round off the column Travel to two decimal places and add it as a new column of the dataframe df

# %% [markdown]
# ###Create a new dataframe df1 containing all the rows of df that meet the condition Speed<45 and display top few elements of the dataframe

# %% [markdown]
# ###How many rows or datatpoints are there in the new dataframe df1?

# %% [markdown]
# ###How many rows had speed>45

# %% [markdown]
# ###Load the segments CSV file

# %% [markdown]
# ###Read the segments file into a dataframe sdf and display the contents of the dataframe

# %% [markdown]
# ###Display the columns names

# %% [markdown]
# ### Rename column XDSegID to code.Verify by displaying the column names again

# %% [markdown]
# ###Join the segments.csv with the dataframe df to get new dataframe named joined

# %% [markdown]
# ###Display all the rows with CITY_NUMBER 1827 and count the number of such instances and report

# %% [markdown]
# ###Report the total number of UNIQUE or DISTINCT segments in the joined dataset

# %% [markdown]
# ###Add a column date to the joined dataframe and report the unique dates

# %% [markdown]
# ##Groupby the date and segment and display the segments that have speed below 45

# %% [markdown]
# ##Groupby the date and segment and display the segments that have speed below 45 in the ascending order

# %% [markdown]
# ###Save the dataframe from the previous step and copy the csv file to your system
