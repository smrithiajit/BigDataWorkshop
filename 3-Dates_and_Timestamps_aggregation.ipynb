# %% [markdown]
# # Dates and Timestamps

# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://downloads.apache.org/spark/spark-3.0.1/spark-3.0.1-bin-hadoop2.7.tgz
# !tar xf spark-3.0.1-bin-hadoop2.7.tgz
# !pip install -q findspark

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.0.1-bin-hadoop2.7"

# %%
import findspark
findspark.init()

# %%
from pyspark.sql import SparkSession
# May take a little while on a local computer
spark = SparkSession.builder.appName("dates").getOrCreate()

# %%
from google.colab import files

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-2a55fc1f-ad20-4097-801e-39a0fe02810f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2a55fc1f-ad20-4097-801e-39a0fe02810f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving appl_stock.csv to appl_stock (1).csv

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
! gdrive/MyDrive/Colab\ Notebooks/BigData_Workshop
# Out:
# /bin/bash: gdrive/MyDrive/Colab Notebooks/BigData_Workshop: Is a directory

# %%
# !ls
# Out:
# 'appl_stock (1).csv'   spark-3.0.1-bin-hadoop2.7
#  appl_stock.csv        spark-3.0.1-bin-hadoop2.7.tgz
#  gdrive		       spark-3.0.1-bin-hadoop2.7.tgz.1
#  sample_data

# %%
df = spark.read.csv("gdrive/MyDrive/Colab\ Notebooks/BigData_Workshop/appl_stock.csv",header=True,inferSchema=True)

# %%
df.show()
# Out:
# +----------+------------------+------------------+------------------+------------------+---------+------------------+
# |      Date|              Open|              High|               Low|             Close|   Volume|         Adj Close|
# +----------+------------------+------------------+------------------+------------------+---------+------------------+
# |2010-01-04|        213.429998|        214.499996|212.38000099999996|        214.009998|123432400|         27.727039|
# |2010-01-05|        214.599998|        215.589994|        213.249994|        214.379993|150476200|27.774976000000002|
# |2010-01-06|        214.379993|            215.23|        210.750004|        210.969995|138040000|27.333178000000004|
# |2010-01-07|            211.75|        212.000006|        209.050005|            210.58|119282800|          27.28265|
# |2010-01-08|        210.299994|        212.000006|209.06000500000002|211.98000499999998|111902700|         27.464034|
# |2010-01-11|212.79999700000002|        213.000002|        208.450005|210.11000299999998|115557400|         27.221758|
# |2010-01-12|209.18999499999998|209.76999500000002|        206.419998|        207.720001|148614900|          26.91211|
# |2010-01-13|        207.870005|210.92999500000002|        204.099998|        210.650002|151473000|          27.29172|
# |2010-01-14|210.11000299999998|210.45999700000002|        209.020004|            209.43|108223500|         27.133657|
# |2010-01-15|210.92999500000002|211.59999700000003|        205.869999|            205.93|148516900|26.680197999999997|
# |2010-01-19|        208.330002|215.18999900000003|        207.240004|        215.039995|182501900|27.860484999999997|
# |2010-01-20|        214.910006|        215.549994|        209.500002|            211.73|153038200|         27.431644|
# |2010-01-21|        212.079994|213.30999599999998|        207.210003|        208.069996|152038600|         26.957455|
# |2010-01-22|206.78000600000001|        207.499996|            197.16|            197.75|220441900|         25.620401|
# |2010-01-25|202.51000200000001|        204.699999|        200.190002|        203.070002|266424900|26.309658000000002|
# |2010-01-26|205.95000100000001|        213.710005|        202.580004|        205.940001|466777500|         26.681494|
# |2010-01-27|        206.849995|            210.58|        199.530001|        207.880005|430642100|26.932840000000002|
# |2010-01-28|        204.930004|        205.500004|        198.699995|        199.289995|293375600|25.819922000000002|
# |2010-01-29|        201.079996|        202.199995|        190.250002|        192.060003|311488100|         24.883208|
# |2010-02-01|192.36999699999998|             196.0|191.29999899999999|        194.729998|187469100|         25.229131|
# +----------+------------------+------------------+------------------+------------------+---------+------------------+
# only showing top 20 rows

# %% [markdown]
# Let's change the datatype of Date from string to timestamp

# %%
from pyspark.sql.types import TimestampType

# %%
df=df.withColumn('Date',df['Date'].cast(TimestampType()))

# %%
df.show()
# Out:
# +-------------------+------------------+------------------+------------------+------------------+---------+------------------+
# |               Date|              Open|              High|               Low|             Close|   Volume|         Adj Close|
# +-------------------+------------------+------------------+------------------+------------------+---------+------------------+
# |2010-01-04 00:00:00|        213.429998|        214.499996|212.38000099999996|        214.009998|123432400|         27.727039|
# |2010-01-05 00:00:00|        214.599998|        215.589994|        213.249994|        214.379993|150476200|27.774976000000002|
# |2010-01-06 00:00:00|        214.379993|            215.23|        210.750004|        210.969995|138040000|27.333178000000004|
# |2010-01-07 00:00:00|            211.75|        212.000006|        209.050005|            210.58|119282800|          27.28265|
# |2010-01-08 00:00:00|        210.299994|        212.000006|209.06000500000002|211.98000499999998|111902700|         27.464034|
# |2010-01-11 00:00:00|212.79999700000002|        213.000002|        208.450005|210.11000299999998|115557400|         27.221758|
# |2010-01-12 00:00:00|209.18999499999998|209.76999500000002|        206.419998|        207.720001|148614900|          26.91211|
# |2010-01-13 00:00:00|        207.870005|210.92999500000002|        204.099998|        210.650002|151473000|          27.29172|
# |2010-01-14 00:00:00|210.11000299999998|210.45999700000002|        209.020004|            209.43|108223500|         27.133657|
# |2010-01-15 00:00:00|210.92999500000002|211.59999700000003|        205.869999|            205.93|148516900|26.680197999999997|
# |2010-01-19 00:00:00|        208.330002|215.18999900000003|        207.240004|        215.039995|182501900|27.860484999999997|
# |2010-01-20 00:00:00|        214.910006|        215.549994|        209.500002|            211.73|153038200|         27.431644|
# |2010-01-21 00:00:00|        212.079994|213.30999599999998|        207.210003|        208.069996|152038600|         26.957455|
# |2010-01-22 00:00:00|206.78000600000001|        207.499996|            197.16|            197.75|220441900|         25.620401|
# |2010-01-25 00:00:00|202.51000200000001|        204.699999|        200.190002|        203.070002|266424900|26.309658000000002|
# |2010-01-26 00:00:00|205.95000100000001|        213.710005|        202.580004|        205.940001|466777500|         26.681494|
# |2010-01-27 00:00:00|        206.849995|            210.58|        199.530001|        207.880005|430642100|26.932840000000002|
# |2010-01-28 00:00:00|        204.930004|        205.500004|        198.699995|        199.289995|293375600|25.819922000000002|
# |2010-01-29 00:00:00|        201.079996|        202.199995|        190.250002|        192.060003|311488100|         24.883208|
# |2010-02-01 00:00:00|192.36999699999998|             196.0|191.29999899999999|        194.729998|187469100|         25.229131|
# +-------------------+------------------+------------------+------------------+------------------+---------+------------------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import *

# %% [markdown]
# Let's add columns with the year,month,day of the week to the dataframe

# %%
dfnew=df.withColumn('year',year('Date')).withColumn('month',month('Date')).withColumn('day',dayofweek('Date'))

# %%
dfnew.show()
# Out:
# +-------------------+------------------+------------------+------------------+------------------+---------+------------------+----+-----+---+
# |               Date|              Open|              High|               Low|             Close|   Volume|         Adj Close|year|month|day|
# +-------------------+------------------+------------------+------------------+------------------+---------+------------------+----+-----+---+
# |2010-01-04 00:00:00|        213.429998|        214.499996|212.38000099999996|        214.009998|123432400|         27.727039|2010|    1|  2|
# |2010-01-05 00:00:00|        214.599998|        215.589994|        213.249994|        214.379993|150476200|27.774976000000002|2010|    1|  3|
# |2010-01-06 00:00:00|        214.379993|            215.23|        210.750004|        210.969995|138040000|27.333178000000004|2010|    1|  4|
# |2010-01-07 00:00:00|            211.75|        212.000006|        209.050005|            210.58|119282800|          27.28265|2010|    1|  5|
# |2010-01-08 00:00:00|        210.299994|        212.000006|209.06000500000002|211.98000499999998|111902700|         27.464034|2010|    1|  6|
# |2010-01-11 00:00:00|212.79999700000002|        213.000002|        208.450005|210.11000299999998|115557400|         27.221758|2010|    1|  2|
# |2010-01-12 00:00:00|209.18999499999998|209.76999500000002|        206.419998|        207.720001|148614900|          26.91211|2010|    1|  3|
# |2010-01-13 00:00:00|        207.870005|210.92999500000002|        204.099998|        210.650002|151473000|          27.29172|2010|    1|  4|
# |2010-01-14 00:00:00|210.11000299999998|210.45999700000002|        209.020004|            209.43|108223500|         27.133657|2010|    1|  5|
# |2010-01-15 00:00:00|210.92999500000002|211.59999700000003|        205.869999|            205.93|148516900|26.680197999999997|2010|    1|  6|
# |2010-01-19 00:00:00|        208.330002|215.18999900000003|        207.240004|        215.039995|182501900|27.860484999999997|2010|    1|  3|
# |2010-01-20 00:00:00|        214.910006|        215.549994|        209.500002|            211.73|153038200|         27.431644|2010|    1|  4|
# |2010-01-21 00:00:00|        212.079994|213.30999599999998|        207.210003|        208.069996|152038600|         26.957455|2010|    1|  5|
# |2010-01-22 00:00:00|206.78000600000001|        207.499996|            197.16|            197.75|220441900|         25.620401|2010|    1|  6|
# |2010-01-25 00:00:00|202.51000200000001|        204.699999|        200.190002|        203.070002|266424900|26.309658000000002|2010|    1|  2|
# |2010-01-26 00:00:00|205.95000100000001|        213.710005|        202.580004|        205.940001|466777500|         26.681494|2010|    1|  3|
# |2010-01-27 00:00:00|        206.849995|            210.58|        199.530001|        207.880005|430642100|26.932840000000002|2010|    1|  4|
# |2010-01-28 00:00:00|        204.930004|        205.500004|        198.699995|        199.289995|293375600|25.819922000000002|2010|    1|  5|
# |2010-01-29 00:00:00|        201.079996|        202.199995|        190.250002|        192.060003|311488100|         24.883208|2010|    1|  6|
# |2010-02-01 00:00:00|192.36999699999998|             196.0|191.29999899999999|        194.729998|187469100|         25.229131|2010|    2|  2|
# +-------------------+------------------+------------------+------------------+------------------+---------+------------------+----+-----+---+
# only showing top 20 rows

# %% [markdown]
# ###Let's change the date to the format MM/dd/yyyy

# %%
import pyspark.sql.functions as F

# %%
dfnew=dfnew.withColumn('date',F.date_format('Date','MM/dd/yyyy'))

# %%
dfnew.show()
# Out:
# +----+------------------+------------------+------------------+------------------+---------+------------------+----+-----+---+
# |date|              Open|              High|               Low|             Close|   Volume|         Adj Close|year|month|day|
# +----+------------------+------------------+------------------+------------------+---------+------------------+----+-----+---+
# |null|        213.429998|        214.499996|212.38000099999996|        214.009998|123432400|         27.727039|2010|    1|  2|
# |null|        214.599998|        215.589994|        213.249994|        214.379993|150476200|27.774976000000002|2010|    1|  3|
# |null|        214.379993|            215.23|        210.750004|        210.969995|138040000|27.333178000000004|2010|    1|  4|
# |null|            211.75|        212.000006|        209.050005|            210.58|119282800|          27.28265|2010|    1|  5|
# |null|        210.299994|        212.000006|209.06000500000002|211.98000499999998|111902700|         27.464034|2010|    1|  6|
# |null|212.79999700000002|        213.000002|        208.450005|210.11000299999998|115557400|         27.221758|2010|    1|  2|
# |null|209.18999499999998|209.76999500000002|        206.419998|        207.720001|148614900|          26.91211|2010|    1|  3|
# |null|        207.870005|210.92999500000002|        204.099998|        210.650002|151473000|          27.29172|2010|    1|  4|
# |null|210.11000299999998|210.45999700000002|        209.020004|            209.43|108223500|         27.133657|2010|    1|  5|
# |null|210.92999500000002|211.59999700000003|        205.869999|            205.93|148516900|26.680197999999997|2010|    1|  6|
# |null|        208.330002|215.18999900000003|        207.240004|        215.039995|182501900|27.860484999999997|2010|    1|  3|
# |null|        214.910006|        215.549994|        209.500002|            211.73|153038200|         27.431644|2010|    1|  4|
# |null|        212.079994|213.30999599999998|        207.210003|        208.069996|152038600|         26.957455|2010|    1|  5|
# |null|206.78000600000001|        207.499996|            197.16|            197.75|220441900|         25.620401|2010|    1|  6|
# |null|202.51000200000001|        204.699999|        200.190002|        203.070002|266424900|26.309658000000002|2010|    1|  2|
# |null|205.95000100000001|        213.710005|        202.580004|        205.940001|466777500|         26.681494|2010|    1|  3|
# |null|        206.849995|            210.58|        199.530001|        207.880005|430642100|26.932840000000002|2010|    1|  4|
# |null|        204.930004|        205.500004|        198.699995|        199.289995|293375600|25.819922000000002|2010|    1|  5|
# |null|        201.079996|        202.199995|        190.250002|        192.060003|311488100|         24.883208|2010|    1|  6|
# |null|192.36999699999998|             196.0|191.29999899999999|        194.729998|187469100|         25.229131|2010|    2|  2|
# +----+------------------+------------------+------------------+------------------+---------+------------------+----+-----+---+
# only showing top 20 rows

# %% [markdown]
# ###Let's check the distinct dates in this dataframe

# %%
dfnew.select('date').distinct().count()
# Out:
# 1

# %%
dfnew2=dfnew.groupBy('year','month').mean()[['year','month','avg(Low)','avg(Close)']]

# %%
dfnew2.columns
# Out:
# ['year', 'month', 'avg(Low)', 'avg(Close)']

# %%
dfnew2=dfnew2.withColumn('low_avg',format_number('avg(Low)',2))

# %%
dfnew2.show()
# Out:
# +----+-----+------------------+------------------+-------+
# |year|month|          avg(Low)|        avg(Close)|low_avg|
# +----+-----+------------------+------------------+-------+
# |2012|   10| 628.2138112380952| 634.7142817142857| 628.21|
# |2010|    7|251.08762104761905|254.94999942857143| 251.09|
# |2010|   12| 320.0027276818182|321.48591127272726| 320.00|
# |2015|    2|124.03105294736844|125.43210478947367| 124.03|
# |2014|    4| 536.2623773809524| 541.0742899999999| 536.26|
# |2015|   12| 110.7418182272727|111.72681809090909| 110.74|
# |2016|    7|       98.00249975| 98.55649979999998|  98.00|
# |2016|   11|108.98857233333332|110.15428528571428| 108.99|
# |2012|    8| 637.1382606521738| 642.6960867391304| 637.14|
# |2013|    2|452.10631984210534| 456.8089530526315| 452.11|
# |2012|    4| 598.6499981000001|       606.0029994| 598.65|
# |2012|   12|      524.96699785|      532.05499735| 524.97|
# |2014|   10|100.81304308695653|101.69956573913043| 100.81|
# |2016|    5|  94.0490471904762| 94.97476157142857|  94.05|
# |2014|   12|111.30500031818183|112.41136418181817| 111.31|
# |2013|    9|476.86149509999996| 480.1844989499999| 476.86|
# |2013|   10| 499.5426088695652|504.74478286956526| 499.54|
# |2014|    5| 598.3328578095238|  603.195721904762| 598.33|
# |2016|    2| 94.71150055000001|        95.7464999|  94.71|
# |2013|   12| 556.4057082857142| 559.6576130952382| 556.41|
# +----+-----+------------------+------------------+-------+
# only showing top 20 rows

# %% [markdown]
# ##Let's groupby the year and find the max and min values of all the columns

# %%
dfnew2.groupBy('year').min().show()
# Out:
# +----+---------+----------+------------------+------------------+
# |year|min(year)|min(month)|     min(avg(Low))|   min(avg(Close))|
# +----+---------+----------+------------------+------------------+
# |2015|     2015|         1|109.33199965000001|110.64150084999999|
# |2013|     2013|         1| 414.7222726818182| 419.7649976818182|
# |2014|     2014|         1| 94.83909018181818| 95.62590850000002|
# |2012|     2012|         1|425.81050165000005|428.57799885000003|
# |2016|     2016|         1|  94.0490471904762| 94.97476157142857|
# |2010|     2010|         1|196.32263184210524|198.79578810526314|
# |2011|     2011|         1|328.23772877272717| 331.0813620909091|
# +----+---------+----------+------------------+------------------+

# %%
dfnew2.groupBy('year').max().show()
# Out:
# +----+---------+----------+------------------+------------------+
# |year|max(year)|max(month)|     max(avg(Low))|   max(avg(Close))|
# +----+---------+----------+------------------+------------------+
# |2015|     2015|        12|127.66299984999998|128.76149974999998|
# |2013|     2013|        12| 556.4057082857142| 559.6576130952382|
# |2014|     2014|        12| 598.3328578095238|  603.195721904762|
# |2012|     2012|        12|  676.095266263158| 681.5684264210527|
# |2016|     2016|        12|114.94142766666668|115.70714309523811|
# |2010|     2010|        12| 320.0027276818182|321.48591127272726|
# |2011|     2011|        12| 391.5257136190477|397.23000076190476|
# +----+---------+----------+------------------+------------------+

# %% [markdown]
# ##Let's groupby the year and find the max a of avg(Low) and sum of avg(Close)

# %%
dfnew2.groupBy('year').agg(F.sum('avg(Close)'),F.max('avg(Low)').alias('avg')).show()
# Out:
# +----+------------------+------------------+
# |year|   sum(avg(Close))|               avg|
# +----+------------------+------------------+
# |2015|1440.6814124810319|127.66299984999998|
# |2013| 5671.432358660076| 556.4057082857142|
# |2014|3586.1754387392443| 598.3328578095238|
# |2012| 6905.342888621221|  676.095266263158|
# |2016| 1254.054804429888|114.94142766666668|
# |2010|3107.8098681626143| 320.0027276818182|
# |2011| 4366.804782148052| 391.5257136190477|
# +----+------------------+------------------+

# %% [markdown]
# ##You can obtain the above result in another way

# %%
dfnew2.groupby('year').agg({'avg(Close)': 'sum','avg(Low)':'max'}).show()
# Out:
# +----+------------------+------------------+
# |year|     max(avg(Low))|   sum(avg(Close))|
# +----+------------------+------------------+
# |2015|127.66299984999998|1440.6814124810319|
# |2013| 556.4057082857142| 5671.432358660076|
# |2014| 598.3328578095238|3586.1754387392443|
# |2012|  676.095266263158| 6905.342888621221|
# |2016|114.94142766666668| 1254.054804429888|
# |2010| 320.0027276818182|3107.8098681626143|
# |2011| 391.5257136190477| 4366.804782148052|
# +----+------------------+------------------+

# %% [markdown]
# ###Let's  find the standard deviation of the column avg(Close)and the distinct values of the same column

# %%
from pyspark.sql.functions import countDistinct, avg,stddev

# %%
dfnew2.columns
# Out:
# ['year', 'month', 'avg(Low)', 'avg(Close)', 'low_avg']

# %%
dfnew2.select(stddev('avg(Close)')).show()
# Out:
# +-----------------------+
# |stddev_samp(avg(Close))|
# +-----------------------+
# |     184.14856115839135|
# +-----------------------+

# %%
dfnew2.select(countDistinct('avg(Close)')).show()
# Out:
# +--------------------------+
# |count(DISTINCT avg(Close))|
# +--------------------------+
# |                        84|
# +--------------------------+

# %% [markdown]
# ###Order by and sort

# %%
# OrderBy
# Ascending
df.orderBy("High").show()
# Out:
# +-------------------+-----------------+-----------------+---------+-----------------+---------+-----------------+
# |               Date|             Open|             High|      Low|            Close|   Volume|        Adj Close|
# +-------------------+-----------------+-----------------+---------+-----------------+---------+-----------------+
# |2014-06-25 00:00:00|        90.209999|        90.699997|89.650002|        90.360001| 36869000|        85.737201|
# |2014-06-26 00:00:00|        90.370003|        91.050003|89.800003|        90.900002| 32629000|        86.249576|
# |2014-06-23 00:00:00|            91.32|        91.620003|90.599998|90.83000200000001| 43694000|        86.183157|
# |2016-05-13 00:00:00|             90.0|91.66999799999999|     90.0|        90.519997| 44392800|89.18571700000001|
# |2014-06-24 00:00:00|            90.75|        91.739998|90.190002|        90.279999| 39036000|        85.661292|
# |2014-06-27 00:00:00|            90.82|             92.0|90.769997|        91.980003| 64029000|        87.274325|
# |2014-06-18 00:00:00|        92.269997|        92.290001|91.349998|            92.18| 33514000|         87.46409|
# |2014-06-19 00:00:00|        92.290001|        92.300003|91.339996|        91.860001| 35528000|        87.160461|
# |2014-06-13 00:00:00|        92.199997|        92.440002|90.879997|        91.279999| 54525000|        86.610132|
# |2014-06-20 00:00:00|        91.849998|        92.550003|90.900002|        90.910004|100898000|        86.259066|
# |2014-06-17 00:00:00|        92.309998|        92.699997|91.800003|92.08000200000001| 29726000|87.36920699999999|
# |2014-06-16 00:00:00|        91.510002|            92.75|91.449997|        92.199997| 35561000|        87.483064|
# |2016-05-12 00:00:00|        92.720001|        92.779999|89.470001|        90.339996| 76314700|         89.00837|
# |2016-06-27 00:00:00|             93.0|        93.050003|     91.5|        92.040001| 45489600|        90.683316|
# |2016-05-06 00:00:00|        93.370003|        93.449997|91.849998|        92.720001| 43458200|91.35329300000001|
# |2016-05-10 00:00:00|93.33000200000001|            93.57|92.110001|93.41999799999999| 33686800|92.04297199999999|
# |2016-05-11 00:00:00|        93.480003|            93.57|92.459999|        92.510002| 28719100|        91.146389|
# |2016-06-28 00:00:00|        92.900002|        93.660004|92.139999|        93.589996| 40444900|        92.210464|
# |2014-06-30 00:00:00|        92.099998|        93.730003|92.089996|            92.93| 49482300|         88.17572|
# |2016-05-09 00:00:00|             93.0|        93.769997|92.589996|        92.790001| 32936400|91.42226099999999|
# +-------------------+-----------------+-----------------+---------+-----------------+---------+-----------------+
# only showing top 20 rows

# %%
# OrderBy
# descending
df.orderBy(df["High"].desc()).show()
# Out:
# +-------------------+-----------------+-----------------+-----------------+-----------------+---------+-----------------+
# |               Date|             Open|             High|              Low|            Close|   Volume|        Adj Close|
# +-------------------+-----------------+-----------------+-----------------+-----------------+---------+-----------------+
# |2012-09-21 00:00:00|       702.409988|       705.070023|699.3599849999999|       700.089989|142897300|         91.09278|
# |2012-09-19 00:00:00|       700.259979|       703.989998|       699.569977|       702.100021| 81718700|91.35431700000001|
# |2012-09-18 00:00:00|       699.879997|       702.329987|696.4199980000001|       701.910004| 93375800|        91.329593|
# |2012-09-20 00:00:00|699.1599809999999|       700.059975|       693.619987|698.6999969999999| 84142100|         90.91192|
# |2012-09-17 00:00:00|       699.349998|       699.799995|694.6100230000001|699.7800219999999| 99507800|        91.052448|
# |2012-09-14 00:00:00|       689.959984|       696.980011|687.8899769999999|691.2800139999999|150118500|        89.946463|
# |2012-09-24 00:00:00|686.8599929999999|       695.119995|682.9999849999999|       690.790016|159941600|        89.882706|
# |2012-09-25 00:00:00|       688.260025|692.7800219999999|       673.000023|673.5400089999999|129697400|87.63820799999999|
# |2012-09-13 00:00:00|       677.370003|685.5000150000001|       674.769997|       682.980011|149590000|        88.866501|
# |2012-09-10 00:00:00|        680.45002|       683.289978|       662.100014|       662.739975|121999500|        86.232952|
# |2012-09-07 00:00:00|       678.050018|       682.480026|        675.77002|        680.43998| 82416600|88.53600300000001|
# |2012-09-27 00:00:00|       664.290024|       682.170006|       660.350014|           681.32|148522500|88.65050699999999|
# |2012-09-28 00:00:00|       678.750008|       681.110008|           666.75|       667.100021|133777700|        86.800263|
# |2012-08-27 00:00:00|       679.989983|       680.870003|673.5400089999999|       675.679977|106752100|        87.916651|
# |2012-09-06 00:00:00|       673.170013|       678.290024|       670.800026|       676.270004| 97799100|87.99342299999999|
# |2012-08-29 00:00:00|       675.250008|       677.669983|       672.600014|       673.469994| 50701700|        87.629097|
# |2012-10-01 00:00:00|671.1599809999999|676.7500150000001|       656.499992|       659.389992|135898700|        85.797067|
# |2012-09-05 00:00:00|       675.570015|       676.350006|       669.599998|       670.230026| 84093800|        87.207526|
# |2012-08-28 00:00:00|674.9799879999999|       676.100014|       670.669983|       674.800011| 66854200|        87.802154|
# |2012-09-04 00:00:00|       665.760017|       675.139992|664.5000150000001|       674.970001| 91973000|        87.824272|
# +-------------------+-----------------+-----------------+-----------------+-----------------+---------+-----------------+
# only showing top 20 rows

# %% [markdown]
# ###Let's look at user defined functions

# %%
def square(x):
  return x**2

# %% [markdown]
# ###Registering UDF with integer type output

# %%
from pyspark.sql.types import FloatType
square_udf=udf(lambda z:square(z), FloatType())

# %%
dfnew2.select('avg(close)',square_udf('avg(close)').alias('avg_close')).show()
# Out:
# +------------------+---------+
# |        avg(close)|avg_close|
# +------------------+---------+
# | 634.7142817142857|402862.22|
# |254.94999942857143|64999.504|
# |321.48591127272726|103353.19|
# |125.43210478947367|15733.213|
# | 541.0742899999999|292761.38|
# |111.72681809090909|12482.882|
# | 98.55649979999998| 9713.384|
# |110.15428528571428|12133.967|
# | 642.6960867391304|413058.25|
# | 456.8089530526315|208674.42|
# |       606.0029994|367239.62|
# |      532.05499735|283082.53|
# |101.69956573913043|10342.802|
# | 94.97476157142857| 9020.205|
# |112.41136418181817|12636.314|
# | 480.1844989499999|230577.16|
# |504.74478286956526| 254767.3|
# |  603.195721904762| 363845.1|
# |        95.7464999| 9167.393|
# | 559.6576130952382|313216.66|
# +------------------+---------+
# only showing top 20 rows

# %% [markdown]
# Let's save the data using repartition and coalesce functions

# %%
dfnew2.repartition(1).write.format('csv').mode('append').save('gdrive/MyDrive/Colab\ Notebooks/BigData_Workshop/homework4.csv')

# %%
files.download('homework4.csv')

# %% [markdown]
# Perfect! Now you know how to work with Date and Timestamp information!
