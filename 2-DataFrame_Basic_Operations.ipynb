# %% [markdown]
# # Basic Operations
#
# This lecture will cover some basic operations with Spark DataFrames.
#
# We will play around with some stock data from Apple.

# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://downloads.apache.org/spark/spark-3.0.1/spark-3.0.1-bin-hadoop2.7.tgz
# !tar xf spark-3.0.1-bin-hadoop2.7.tgz
# !pip install -q findspark

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.0.1-bin-hadoop2.7"

# %%
import findspark
findspark.init()

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("Operations").getOrCreate()

# %%
from google.colab import files

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-9321e9db-7595-4868-b248-0ad1ed9e5203" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9321e9db-7595-4868-b248-0ad1ed9e5203">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving appl_stock.csv to appl_stock.csv

# %% [markdown]
# Let's read in the data

# %%
# Let Spark know about the header and infer the Schema types!
df = spark.read.csv('appl_stock.csv',inferSchema=True,header=True)

# %%
df.show()
# Out:
# +----------+------------------+------------------+------------------+------------------+---------+------------------+
# |      Date|              Open|              High|               Low|             Close|   Volume|         Adj Close|
# +----------+------------------+------------------+------------------+------------------+---------+------------------+
# |2010-01-04|        213.429998|        214.499996|212.38000099999996|        214.009998|123432400|         27.727039|
# |2010-01-05|        214.599998|        215.589994|        213.249994|        214.379993|150476200|27.774976000000002|
# |2010-01-06|        214.379993|            215.23|        210.750004|        210.969995|138040000|27.333178000000004|
# |2010-01-07|            211.75|        212.000006|        209.050005|            210.58|119282800|          27.28265|
# |2010-01-08|        210.299994|        212.000006|209.06000500000002|211.98000499999998|111902700|         27.464034|
# |2010-01-11|212.79999700000002|        213.000002|        208.450005|210.11000299999998|115557400|         27.221758|
# |2010-01-12|209.18999499999998|209.76999500000002|        206.419998|        207.720001|148614900|          26.91211|
# |2010-01-13|        207.870005|210.92999500000002|        204.099998|        210.650002|151473000|          27.29172|
# |2010-01-14|210.11000299999998|210.45999700000002|        209.020004|            209.43|108223500|         27.133657|
# |2010-01-15|210.92999500000002|211.59999700000003|        205.869999|            205.93|148516900|26.680197999999997|
# |2010-01-19|        208.330002|215.18999900000003|        207.240004|        215.039995|182501900|27.860484999999997|
# |2010-01-20|        214.910006|        215.549994|        209.500002|            211.73|153038200|         27.431644|
# |2010-01-21|        212.079994|213.30999599999998|        207.210003|        208.069996|152038600|         26.957455|
# |2010-01-22|206.78000600000001|        207.499996|            197.16|            197.75|220441900|         25.620401|
# |2010-01-25|202.51000200000001|        204.699999|        200.190002|        203.070002|266424900|26.309658000000002|
# |2010-01-26|205.95000100000001|        213.710005|        202.580004|        205.940001|466777500|         26.681494|
# |2010-01-27|        206.849995|            210.58|        199.530001|        207.880005|430642100|26.932840000000002|
# |2010-01-28|        204.930004|        205.500004|        198.699995|        199.289995|293375600|25.819922000000002|
# |2010-01-29|        201.079996|        202.199995|        190.250002|        192.060003|311488100|         24.883208|
# |2010-02-01|192.36999699999998|             196.0|191.29999899999999|        194.729998|187469100|         25.229131|
# +----------+------------------+------------------+------------------+------------------+---------+------------------+
# only showing top 20 rows

# %% [markdown]
# Check the names of the columns

# %%
df.columns
# Out:
# ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Adj Close']

# %% [markdown]
# Check the schema

# %%
df.printSchema()
# Out:
# root
#  |-- Date: string (nullable = true)
#  |-- Open: double (nullable = true)
#  |-- High: double (nullable = true)
#  |-- Low: double (nullable = true)
#  |-- Close: double (nullable = true)
#  |-- Volume: integer (nullable = true)
#  |-- Adj Close: double (nullable = true)

# %% [markdown]
# ###Renaming columns

# %%
df1=df.withColumnRenamed('Adj Close','adj_close')

# %%
df1.show()
# Out:
# +----------+------------------+------------------+------------------+------------------+---------+------------------+
# |      Date|              Open|              High|               Low|             Close|   Volume|         adj_close|
# +----------+------------------+------------------+------------------+------------------+---------+------------------+
# |2010-01-04|        213.429998|        214.499996|212.38000099999996|        214.009998|123432400|         27.727039|
# |2010-01-05|        214.599998|        215.589994|        213.249994|        214.379993|150476200|27.774976000000002|
# |2010-01-06|        214.379993|            215.23|        210.750004|        210.969995|138040000|27.333178000000004|
# |2010-01-07|            211.75|        212.000006|        209.050005|            210.58|119282800|          27.28265|
# |2010-01-08|        210.299994|        212.000006|209.06000500000002|211.98000499999998|111902700|         27.464034|
# |2010-01-11|212.79999700000002|        213.000002|        208.450005|210.11000299999998|115557400|         27.221758|
# |2010-01-12|209.18999499999998|209.76999500000002|        206.419998|        207.720001|148614900|          26.91211|
# |2010-01-13|        207.870005|210.92999500000002|        204.099998|        210.650002|151473000|          27.29172|
# |2010-01-14|210.11000299999998|210.45999700000002|        209.020004|            209.43|108223500|         27.133657|
# |2010-01-15|210.92999500000002|211.59999700000003|        205.869999|            205.93|148516900|26.680197999999997|
# |2010-01-19|        208.330002|215.18999900000003|        207.240004|        215.039995|182501900|27.860484999999997|
# |2010-01-20|        214.910006|        215.549994|        209.500002|            211.73|153038200|         27.431644|
# |2010-01-21|        212.079994|213.30999599999998|        207.210003|        208.069996|152038600|         26.957455|
# |2010-01-22|206.78000600000001|        207.499996|            197.16|            197.75|220441900|         25.620401|
# |2010-01-25|202.51000200000001|        204.699999|        200.190002|        203.070002|266424900|26.309658000000002|
# |2010-01-26|205.95000100000001|        213.710005|        202.580004|        205.940001|466777500|         26.681494|
# |2010-01-27|        206.849995|            210.58|        199.530001|        207.880005|430642100|26.932840000000002|
# |2010-01-28|        204.930004|        205.500004|        198.699995|        199.289995|293375600|25.819922000000002|
# |2010-01-29|        201.079996|        202.199995|        190.250002|        192.060003|311488100|         24.883208|
# |2010-02-01|192.36999699999998|             196.0|191.29999899999999|        194.729998|187469100|         25.229131|
# +----------+------------------+------------------+------------------+------------------+---------+------------------+
# only showing top 20 rows

# %% [markdown]
# ## Filtering Data

# %%
df1=df.filter(df.High>214)

# %%
df1.show()
# Out:
# +----------+------------------+------------------+------------------+------------------+---------+------------------+
# |      Date|              Open|              High|               Low|             Close|   Volume|         Adj Close|
# +----------+------------------+------------------+------------------+------------------+---------+------------------+
# |2010-01-04|        213.429998|        214.499996|212.38000099999996|        214.009998|123432400|         27.727039|
# |2010-01-05|        214.599998|        215.589994|        213.249994|        214.379993|150476200|27.774976000000002|
# |2010-01-06|        214.379993|            215.23|        210.750004|        210.969995|138040000|27.333178000000004|
# |2010-01-19|        208.330002|215.18999900000003|        207.240004|        215.039995|182501900|27.860484999999997|
# |2010-01-20|        214.910006|        215.549994|        209.500002|            211.73|153038200|         27.431644|
# |2010-03-05|        214.940006|219.69999500000003|214.62999900000003|218.95000499999998|224905100|28.367064000000003|
# |2010-03-08|220.01000200000001|        220.090004|        218.250002|        219.079994|107472400|         28.383906|
# |2010-03-09|218.31000299999997|        224.999996|        217.889994|        223.020004|230064800|28.894371999999997|
# |2010-03-10|        223.829996|225.48000699999997|223.19999500000003|224.83999300000002|149054500|29.130167999999998|
# |2010-03-11|        223.909998|        225.500008|        223.319998|        225.500008|101425100|          29.21568|
# |2010-03-12|         227.37001|227.72999199999998|            225.75|        226.600006|104080900|29.358195000000002|
# |2010-03-15|225.38000499999998|        225.500008|        220.249994|223.83999599999999|123375700|29.000609000000004|
# |2010-03-16|        224.180004|        224.979996|        222.510006|224.44999700000002|111727000|         29.079641|
# |2010-03-17|        224.899994|226.44998900000002|223.26999700000002|224.12000299999997|112739200|         29.036887|
# |2010-03-18|        224.100002|        224.999996|222.60999500000003|        224.650002| 85527400|29.105553000000004|
# |2010-03-19|224.79000499999998|        225.240002|221.23000299999998|            222.25|139861400|          28.79461|
# |2010-03-22|220.46999900000003|        225.999992|        220.150005|        224.750004|114104900|29.118509999999997|
# |2010-03-23|        225.640011|        228.780003|        224.100002|        228.359993|150607800|         29.586218|
# |2010-03-24|227.64000299999998|        230.200008|227.50998700000002|229.37000299999997|149445100|         29.717075|
# |2010-03-25|        230.919998|        230.970013|        226.250011|        226.649994|135571100|         29.364671|
# +----------+------------------+------------------+------------------+------------------+---------+------------------+
# only showing top 20 rows

# %% [markdown]
# Let's see how many datapoints ar there in the new datframe after filtering

# %%
df1.count()
df.count()
print("Number of records dropped=",df.count()-df1.count())
# Out:
# Number of records dropped= 685

# %% [markdown]
# Let's apply a filter based on multiple conditions i.e. High<230 and Low>220

# %%
df2=df.filter((df.High<230)& (df.Low>220))

# %%
df.columns
# Out:
# ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Adj Close']

# %% [markdown]
# Let's apply a filter based on multiple conditions i.e. High<230 or Low>220

# %%
df3=df.filter((df.High==196)|(df.Low<220))

# %%
df3.show()
# Out:
# +----------+------------------+------------------+------------------+------------------+---------+------------------+
# |      Date|              Open|              High|               Low|             Close|   Volume|         Adj Close|
# +----------+------------------+------------------+------------------+------------------+---------+------------------+
# |2010-01-04|        213.429998|        214.499996|212.38000099999996|        214.009998|123432400|         27.727039|
# |2010-01-05|        214.599998|        215.589994|        213.249994|        214.379993|150476200|27.774976000000002|
# |2010-01-06|        214.379993|            215.23|        210.750004|        210.969995|138040000|27.333178000000004|
# |2010-01-07|            211.75|        212.000006|        209.050005|            210.58|119282800|          27.28265|
# |2010-01-08|        210.299994|        212.000006|209.06000500000002|211.98000499999998|111902700|         27.464034|
# |2010-01-11|212.79999700000002|        213.000002|        208.450005|210.11000299999998|115557400|         27.221758|
# |2010-01-12|209.18999499999998|209.76999500000002|        206.419998|        207.720001|148614900|          26.91211|
# |2010-01-13|        207.870005|210.92999500000002|        204.099998|        210.650002|151473000|          27.29172|
# |2010-01-14|210.11000299999998|210.45999700000002|        209.020004|            209.43|108223500|         27.133657|
# |2010-01-15|210.92999500000002|211.59999700000003|        205.869999|            205.93|148516900|26.680197999999997|
# |2010-01-19|        208.330002|215.18999900000003|        207.240004|        215.039995|182501900|27.860484999999997|
# |2010-01-20|        214.910006|        215.549994|        209.500002|            211.73|153038200|         27.431644|
# |2010-01-21|        212.079994|213.30999599999998|        207.210003|        208.069996|152038600|         26.957455|
# |2010-01-22|206.78000600000001|        207.499996|            197.16|            197.75|220441900|         25.620401|
# |2010-01-25|202.51000200000001|        204.699999|        200.190002|        203.070002|266424900|26.309658000000002|
# |2010-01-26|205.95000100000001|        213.710005|        202.580004|        205.940001|466777500|         26.681494|
# |2010-01-27|        206.849995|            210.58|        199.530001|        207.880005|430642100|26.932840000000002|
# |2010-01-28|        204.930004|        205.500004|        198.699995|        199.289995|293375600|25.819922000000002|
# |2010-01-29|        201.079996|        202.199995|        190.250002|        192.060003|311488100|         24.883208|
# |2010-02-01|192.36999699999998|             196.0|191.29999899999999|        194.729998|187469100|         25.229131|
# +----------+------------------+------------------+------------------+------------------+---------+------------------+
# only showing top 20 rows

# %% [markdown]
# Let's look for nulls in the dataset

# %%
df3.filter(df.Date.isNull()| df.Open.isNull()).show()
# Out:
# +----+----+----+---+-----+------+---------+
# |Date|Open|High|Low|Close|Volume|Adj Close|
# +----+----+----+---+-----+------+---------+
# +----+----+----+---+-----+------+---------+

# %% [markdown]
# Let's apply a filter based on 3 conditions High=196,Volume=187469100 and Close>195

# %%
df3=df3.filter(((df.High==196)|(df.Volume==187469100))& (df.Close>195))

# %% [markdown]
# You can rewrite the code as shown below. Both will give you the correct result

# %%
df3=df.filter(((df['High']==196)|(df['Volume']==187469100))& (df['Close']>195))

# %%
df3.show()
# Out:
# +----------+------------------+-----+----------+----------+---------+------------------+
# |      Date|              Open| High|       Low|     Close|   Volume|         Adj Close|
# +----------+------------------+-----+----------+----------+---------+------------------+
# |2010-02-05|192.63000300000002|196.0|190.850002|195.460001|212576700|25.323710000000002|
# +----------+------------------+-----+----------+----------+---------+------------------+

# %% [markdown]
# ###Changing the datatype and using concat,substring functions

# %% [markdown]
# Let's look at some other interesting and useful functions. If I want an additional column in the format Date:Open I can use the 'concat' function

# %%
from pyspark.sql import functions as F

# %%
df4=df3.withColumn('Concatenated',F.concat(F.col('Date'),F.lit(' : '),F.col('Open')))
df4.show(5)
# Out:
# +----------+----------+----------+------------------+------------------+---------+------------------+--------------------+
# |      Date|      Open|      High|               Low|             Close|   Volume|         Adj Close|        Concatenated|
# +----------+----------+----------+------------------+------------------+---------+------------------+--------------------+
# |2010-01-04|213.429998|214.499996|212.38000099999996|        214.009998|123432400|         27.727039|2010-01-04 : 213....|
# |2010-01-05|214.599998|215.589994|        213.249994|        214.379993|150476200|27.774976000000002|2010-01-05 : 214....|
# |2010-01-06|214.379993|    215.23|        210.750004|        210.969995|138040000|27.333178000000004|2010-01-06 : 214....|
# |2010-01-07|    211.75|212.000006|        209.050005|            210.58|119282800|          27.28265| 2010-01-07 : 211.75|
# |2010-01-08|210.299994|212.000006|209.06000500000002|211.98000499999998|111902700|         27.464034|2010-01-08 : 210....|
# +----------+----------+----------+------------------+------------------+---------+------------------+--------------------+
# only showing top 5 rows

# %% [markdown]
# Now let's create a new column Datenew with Date as a timestamp

# %%
from pyspark.sql.types import TimestampType,IntegerType,FloatType,DoubleType

# %%
df4=df4.withColumn('Datenew',F.col('Date').cast(TimestampType()))

# %%
df4.dtypes
# Out:
# [('Date', 'string'),
#  ('Open', 'double'),
#  ('High', 'double'),
#  ('Low', 'double'),
#  ('Close', 'double'),
#  ('Volume', 'int'),
#  ('Adj Close', 'double'),
#  ('Concatenated', 'string'),
#  ('Datenew', 'timestamp')]

# %% [markdown]
# Now let's change the datatype of Volume from integer to double

# %%
df4=df3.withColumn('Volume',F.col('Volume').cast(DoubleType()))

# %%
df4.show()
# Out:
# +----------+------------------+------------------+------------------+------------------+----------+------------------+
# |      Date|              Open|              High|               Low|             Close|    Volume|         Adj Close|
# +----------+------------------+------------------+------------------+------------------+----------+------------------+
# |2010-01-04|        213.429998|        214.499996|212.38000099999996|        214.009998|1.234324E8|         27.727039|
# |2010-01-05|        214.599998|        215.589994|        213.249994|        214.379993|1.504762E8|27.774976000000002|
# |2010-01-06|        214.379993|            215.23|        210.750004|        210.969995|  1.3804E8|27.333178000000004|
# |2010-01-07|            211.75|        212.000006|        209.050005|            210.58|1.192828E8|          27.28265|
# |2010-01-08|        210.299994|        212.000006|209.06000500000002|211.98000499999998|1.119027E8|         27.464034|
# |2010-01-11|212.79999700000002|        213.000002|        208.450005|210.11000299999998|1.155574E8|         27.221758|
# |2010-01-12|209.18999499999998|209.76999500000002|        206.419998|        207.720001|1.486149E8|          26.91211|
# |2010-01-13|        207.870005|210.92999500000002|        204.099998|        210.650002| 1.51473E8|          27.29172|
# |2010-01-14|210.11000299999998|210.45999700000002|        209.020004|            209.43|1.082235E8|         27.133657|
# |2010-01-15|210.92999500000002|211.59999700000003|        205.869999|            205.93|1.485169E8|26.680197999999997|
# |2010-01-19|        208.330002|215.18999900000003|        207.240004|        215.039995|1.825019E8|27.860484999999997|
# |2010-01-20|        214.910006|        215.549994|        209.500002|            211.73|1.530382E8|         27.431644|
# |2010-01-21|        212.079994|213.30999599999998|        207.210003|        208.069996|1.520386E8|         26.957455|
# |2010-01-22|206.78000600000001|        207.499996|            197.16|            197.75|2.204419E8|         25.620401|
# |2010-01-25|202.51000200000001|        204.699999|        200.190002|        203.070002|2.664249E8|26.309658000000002|
# |2010-01-26|205.95000100000001|        213.710005|        202.580004|        205.940001|4.667775E8|         26.681494|
# |2010-01-27|        206.849995|            210.58|        199.530001|        207.880005|4.306421E8|26.932840000000002|
# |2010-01-28|        204.930004|        205.500004|        198.699995|        199.289995|2.933756E8|25.819922000000002|
# |2010-01-29|        201.079996|        202.199995|        190.250002|        192.060003|3.114881E8|         24.883208|
# |2010-02-01|192.36999699999998|             196.0|191.29999899999999|        194.729998|1.874691E8|         25.229131|
# +----------+------------------+------------------+------------------+------------------+----------+------------------+
# only showing top 20 rows

# %%
df4.withColumn('month',F.substring(F.col('Date'),6,2)).show()
# Out:
# +----------+------------------+------------------+------------------+------------------+---------+------------------+--------------------+-------------------+-----+
# |      Date|              Open|              High|               Low|             Close|   Volume|         Adj Close|        Concatenated|            Datenew|month|
# +----------+------------------+------------------+------------------+------------------+---------+------------------+--------------------+-------------------+-----+
# |2010-01-04|        213.429998|        214.499996|212.38000099999996|        214.009998|123432400|         27.727039|2010-01-04 : 213....|2010-01-04 00:00:00|   01|
# |2010-01-05|        214.599998|        215.589994|        213.249994|        214.379993|150476200|27.774976000000002|2010-01-05 : 214....|2010-01-05 00:00:00|   01|
# |2010-01-06|        214.379993|            215.23|        210.750004|        210.969995|138040000|27.333178000000004|2010-01-06 : 214....|2010-01-06 00:00:00|   01|
# |2010-01-07|            211.75|        212.000006|        209.050005|            210.58|119282800|          27.28265| 2010-01-07 : 211.75|2010-01-07 00:00:00|   01|
# |2010-01-08|        210.299994|        212.000006|209.06000500000002|211.98000499999998|111902700|         27.464034|2010-01-08 : 210....|2010-01-08 00:00:00|   01|
# |2010-01-11|212.79999700000002|        213.000002|        208.450005|210.11000299999998|115557400|         27.221758|2010-01-11 : 212....|2010-01-11 00:00:00|   01|
# |2010-01-12|209.18999499999998|209.76999500000002|        206.419998|        207.720001|148614900|          26.91211|2010-01-12 : 209....|2010-01-12 00:00:00|   01|
# |2010-01-13|        207.870005|210.92999500000002|        204.099998|        210.650002|151473000|          27.29172|2010-01-13 : 207....|2010-01-13 00:00:00|   01|
# |2010-01-14|210.11000299999998|210.45999700000002|        209.020004|            209.43|108223500|         27.133657|2010-01-14 : 210....|2010-01-14 00:00:00|   01|
# |2010-01-15|210.92999500000002|211.59999700000003|        205.869999|            205.93|148516900|26.680197999999997|2010-01-15 : 210....|2010-01-15 00:00:00|   01|
# |2010-01-19|        208.330002|215.18999900000003|        207.240004|        215.039995|182501900|27.860484999999997|2010-01-19 : 208....|2010-01-19 00:00:00|   01|
# |2010-01-20|        214.910006|        215.549994|        209.500002|            211.73|153038200|         27.431644|2010-01-20 : 214....|2010-01-20 00:00:00|   01|
# |2010-01-21|        212.079994|213.30999599999998|        207.210003|        208.069996|152038600|         26.957455|2010-01-21 : 212....|2010-01-21 00:00:00|   01|
# |2010-01-22|206.78000600000001|        207.499996|            197.16|            197.75|220441900|         25.620401|2010-01-22 : 206....|2010-01-22 00:00:00|   01|
# |2010-01-25|202.51000200000001|        204.699999|        200.190002|        203.070002|266424900|26.309658000000002|2010-01-25 : 202....|2010-01-25 00:00:00|   01|
# |2010-01-26|205.95000100000001|        213.710005|        202.580004|        205.940001|466777500|         26.681494|2010-01-26 : 205....|2010-01-26 00:00:00|   01|
# |2010-01-27|        206.849995|            210.58|        199.530001|        207.880005|430642100|26.932840000000002|2010-01-27 : 206....|2010-01-27 00:00:00|   01|
# |2010-01-28|        204.930004|        205.500004|        198.699995|        199.289995|293375600|25.819922000000002|2010-01-28 : 204....|2010-01-28 00:00:00|   01|
# |2010-01-29|        201.079996|        202.199995|        190.250002|        192.060003|311488100|         24.883208|2010-01-29 : 201....|2010-01-29 00:00:00|   01|
# |2010-02-01|192.36999699999998|             196.0|191.29999899999999|        194.729998|187469100|         25.229131|2010-02-01 : 192....|2010-02-01 00:00:00|   02|
# +----------+------------------+------------------+------------------+------------------+---------+------------------+--------------------+-------------------+-----+
# only showing top 20 rows

# %% [markdown]
# Now, let's try collecting the results as Python objects and convert it to a dictionary. The ".collect" function will bring your result to the driver.If your result is  very big this is not adviseable since it will cause out of memory error.

# %%
# Collecting results as Python objects
result=df.filter((df['High']==196)|(df['Volume']==187469100)).collect()

# %%
result
# Out:
# [Row(Date='2010-02-01', Open=192.36999699999998, High=196.0, Low=191.29999899999999, Close=194.729998, Volume=187469100, Adj Close=25.229131),
#  Row(Date='2010-02-05', Open=192.63000300000002, High=196.0, Low=190.850002, Close=195.460001, Volume=212576700, Adj Close=25.323710000000002)]

# %%
type(result)
# Out:
# list

# %%
result[1]
# Out:
# Row(Date='2010-02-05', Open=192.63000300000002, High=196.0, Low=190.850002, Close=195.460001, Volume=212576700, Adj Close=25.323710000000002)

# %%
newdict=result[0].asDict()

# %%
newdict
# Out:
# {'Adj Close': 25.229131,
#  'Close': 194.729998,
#  'Date': '2010-02-01',
#  'High': 196.0,
#  'Low': 191.29999899999999,
#  'Open': 192.36999699999998,
#  'Volume': 187469100}

# %% [markdown]
# ###Save data

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
df5=df4.toPandas()

df5.to_csv('datafromcolab.csv')
# Out:
# cp: cannot stat 'data.csv': No such file or directory

# %%
# !cp datafromcolab.csv "drive/My Drive/"
# Out:
# cp: cannot stat 'data.csv': No such file or directory

# %%
df4.repartition(1).write.format('csv').mode('append').save('homework')

# %%
# !ls -lrt homework
# Out:
# total 56
# -rw-r--r-- 1 root root 53822 Dec  2 19:53 part-00000-76f3e14d-25e4-44c1-91a4-304a4cae5500-c000.csv
# -rw-r--r-- 1 root root     0 Dec  2 19:53 _SUCCESS

# %%
# !cp -r homework "drive/My Drive/"

# %%
df4.coalesce(1).write.format('csv').mode('Overwrite').save('homework_coalesce')
# !cp -r homework_coalesce "drive/My Drive"

# %%
# !ls -lrt homework{}

# %% [markdown]
# Rows can be called to turn into dictionaries

# %% [markdown]
# That is all for now Great Job!
